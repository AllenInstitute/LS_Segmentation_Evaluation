# %% [markdown]
# ### Import Modules and Pathways

# %%
# Set pathways and initialize model
import os
import re
import time
import torch

import numpy as np
import pandas as pd
import utils.preprocess as preprocess
import utils.evaluate as evaluate

from collections import defaultdict
from cellpose import models, core, io

# set pathways to test files
# Paths to annotated test data
base_dir = '/home/elyse/Documents/GitHub/LS_evaluation_tool/test_data/images/'
output_root = '/home/elyse/Documents/GitHub/LS_evaluation_tool/test_data/cellpose_output'

# create output directory if it doesn't already exist
if not os.path.exists(output_root):
    os.mkdir(output_root)

# have cellpose log run
io.logger_setup()

# initialize model
use_GPU = core.use_gpu()
model = models.Cellpose(gpu = use_GPU, model_type = 'nuclei')
# Out:
# 2022-11-30 16:40:05,394 [INFO] WRITING LOG OUTPUT TO /home/elyse/.cellpose/run.log
# 2022-11-30 16:40:05,409 [INFO] ** TORCH CUDA version installed and working. **
# 2022-11-30 16:40:05,411 [INFO] ** TORCH CUDA version installed and working. **
# 2022-11-30 16:40:05,411 [INFO] >>>> using GPU
# 2022-11-30 16:40:05,412 [INFO] >> nuclei << model set to be used
# 2022-11-30 16:40:05,586 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)

# %% [markdown]
# ### Import Annotation Data

# %%
# Get annotated data and image file paths
blocks = defaultdict(dict)

# loop through base directory and collect all data from "block_#" subfolders
for root, dirs, files in os.walk(base_dir):
    if 'block' in root: 
        for file in files:
            try:
                block_num = re.findall('[0-9]', file)[0]
            except:
                continue
            if 'signal' in file:
                blocks[block_num]['signal'] = os.path.join(root, file)
            elif 'background' in file:
                blocks[block_num]['background'] = os.path.join(root, file)
            elif 'detect' in file:
                blocks[block_num]['detect'] = preprocess.get_locations(os.path.join(root, file))
            else:
                blocks[block_num]['reject'] = preprocess.get_locations(os.path.join(root, file))

# print info on blocks        
for key in blocks.keys():
    try:
        rejected = len(blocks[key]['reject'])
    except:
        rejected = 0
    print('Pulled annotation data for block {0}: {1} cells and {2} noncells.'.format(str(key), len(blocks[key]['detect']), rejected))
# Out:
# Pulled annotation data for block 4: 2168 cells and 0 noncells.
# Pulled annotation data for block 1: 1751 cells and 2 noncells.
# Pulled annotation data for block 3: 410 cells and 5 noncells.
# Pulled annotation data for block 2: 1641 cells and 2 noncells.

# %% [markdown]
# ### Initialize Pretrained Cellpose

# %%
# There are 3 ways to run 3D Cellpose. The first 2 are exrapolating 2D to 3D
# This is very time consuming if ytou do not GPU access
# The Third way is using new Cellpose3D repo in other script
import skimage.io
import utils.preprocess as pp
from skimage.measure import regionprops

# Set parameters
# grayscale=0, R=1, G=2, B=3
# channels = [cytoplasm, nucleus]
# channels = [0,0] # IF YOU HAVE GRAYSCALE
# flow_threshold not used for 3D (see git code) so dont need to mess with
channels = [0,0]
prob_thresh = 0.9
stitch_thresh = 0.5
diameter = 9 # unit = px
min_size = 60
detect_times = defaultdict(int)

# which methods and channels do you want to run for cellpose
methods = ['flow', 'stitch']
chs = ['signal', 'background']

# parameters for preprocessing
bkg_sub = True
estimator = 'MedianBackground'
pad = 50

for method in methods:
    start_detect = time.time()
    for key in blocks.keys():
        for ch in chs:
            fname = os.path.basename(blocks[key][ch])[:-4]
            img = skimage.io.imread(blocks[key][ch])
            
            if bkg_sub:
                img = pp.astro_preprocess(img, estimator, pad = pad)
            
            if method == 'flow':
                masks, flows, styles, diams = model.eval(img, channels = channels, diameter = diameter, cellprob_threshold = prob_thresh, 
                                                         do_3D = True, min_size = min_size)
            elif method == 'stitch':
                masks, flows, styles, diams = model.eval(img, channels = channels, diameter = diameter, cellprob_threshold = prob_thresh, 
                                                         do_3D = False, stitch_threshold = stitch_thresh)

            # get centroids from masks. see: https://github.com/MouseLand/cellpose/issues/337
            centroids = []
            candidates = regionprops(masks)
            for c in range(len(candidates)):
                location = [int(x) for x in candidates[c]['centroid']]
                centroids.append(location[::-1])
        
            if ch == 'signal':
                blocks[key]['pred_detect_' + method] = centroids
            else:
                blocks[key]['pred_reject_' + method] = centroids
            
            # save masks and flows
            output_path = os.path.join(output_root, method)

            # create output directory if it doesn't already exist
            if not os.path.exists(output_path):
                os.mkdir(output_path)
            
            # save masks as tif 
            io.save_masks(img, masks, flows, blocks[key][ch], png = False, tif = True, channels = channels, 
                          save_flows = True, save_outlines = True, savedir = output_path)
            
            # save all data for plotting
            io.masks_flows_to_seg(img, masks, flows, diams, os.path.join(output_path, fname), channels=None)

    detect_times[method] = time.time() - start_detect
# Out:
# 2022-11-30 16:40:12,512 [INFO] ~~~ FINDING MASKS ~~~
# 2022-11-30 16:40:12,583 [INFO] multi-stack tiff read in as having 150 planes 1 channels
# 2022-11-30 16:40:14,114 [INFO] running YX: 150 planes of size (350, 350)
# 2022-11-30 16:40:14,337 [INFO] 0%|          | 0/75 [00:00<?, ?it/s]
# 2022-11-30 16:40:14,514 [INFO] 1%|1         | 1/75 [00:00<00:13,  5.68it/s]
# 2022-11-30 16:40:14,694 [INFO] 3%|2         | 2/75 [00:00<00:12,  5.62it/s]
# 2022-11-30 16:40:14,875 [INFO] 4%|4         | 3/75 [00:00<00:12,  5.57it/s]
# 2022-11-30 16:40:15,054 [INFO] 5%|5         | 4/75 [00:00<00:12,  5.58it/s]
# 2022-11-30 16:40:15,222 [INFO] 7%|6         | 5/75 [00:00<00:12,  5.70it/s]
# 2022-11-30 16:40:15,394 [INFO] 8%|8         | 6/75 [00:01<00:12,  5.74it/s]
# 2022-11-30 16:40:15,562 [INFO] 9%|9         | 7/75 [00:01<00:11,  5.81it/s]
# 2022-11-30 16:40:15,733 [INFO] 11%|#         | 8/75 [00:01<00:11,  5.83it/s]
# 2022-11-30 16:40:15,907 [INFO] 12%|#2        | 9/75 [00:01<00:11,  5.80it/s]
# 2022-11-30 16:40:16,076 [INFO] 13%|#3        | 10/75 [00:01<00:11,  5.83it/s]
# 2022-11-30 16:40:16,252 [INFO] 15%|#4        | 11/75 [00:01<00:11,  5.79it/s]
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/cellpose/models.py in eval(self, x, batch_size, channels, channel_axis, z_axis, invert, normalize, diameter, do_3D, anisotropy, net_avg, augment, tile, tile_overlap, resample, interp, flow_threshold, cellprob_threshold, min_size, stitch_threshold, rescale, progress, model_loaded)
#     236         tic = time.time()
#     237         models_logger.info('~~~ FINDING MASKS ~~~')
# --> 238         masks, flows, styles = self.cp.eval(x,
#     239                                             batch_size=batch_size,
#     240                                             invert=invert,
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/cellpose/models.py in eval(self, x, batch_size, channels, channel_axis, z_axis, normalize, invert, rescale, diameter, do_3D, anisotropy, net_avg, augment, tile, tile_overlap, resample, interp, flow_threshold, cellprob_threshold, compute_masks, min_size, stitch_threshold, progress, loop_run, model_loaded)
#     549                 rescale = self.diam_mean / diameter
#     550
# --> 551             masks, styles, dP, cellprob, p = self._run_cp(x,
#     552                                                           compute_masks=compute_masks,
#     553                                                           normalize=normalize,
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/cellpose/models.py in _run_cp(self, x, compute_masks, normalize, invert, rescale, net_avg, resample, augment, tile, tile_overlap, cellprob_threshold, flow_threshold, min_size, interp, anisotropy, do_3D, stitch_threshold)
#     638             niter = 200 if (do_3D and not resample) else (1 / rescale * 200)
#     639             if do_3D:
# --> 640                 masks, p = dynamics.compute_masks(dP, cellprob, niter=niter,
#     641                                                       cellprob_threshold=cellprob_threshold,
#     642                                                       flow_threshold=flow_threshold,
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/cellpose/dynamics.py in compute_masks(dP, cellprob, p, niter, cellprob_threshold, flow_threshold, interp, do_3D, min_size, resize, use_gpu, device)
#     753     # maybe better would be to rescale the min_size and hole_size parameters to do the
#     754     # cleanup at the prediction scale, or switch depending on which one is bigger...
# --> 755     mask = utils.fill_holes_and_remove_small_masks(mask, min_size=min_size)
#     756
#     757     if mask.dtype==np.uint32:
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/cellpose/utils.py in fill_holes_and_remove_small_masks(masks, min_size)
#     443         raise ValueError('masks_to_outlines takes 2D or 3D array, not %dD array'%masks.ndim)
#     444
# --> 445     slices = find_objects(masks)
#     446     j = 0
#     447     for i,slc in enumerate(slices):
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/scipy/ndimage/_measurements.py in find_objects(input, max_label)
#     303         max_label = input.max()
#     304
# --> 305     return _nd_image.find_objects(input, max_label)
#     306
#     307
#
# KeyboardInterrupt:

# %% [markdown]
# ### Cellpose Outputs and Profile

# %%
# get time to run each method
for method in methods:
    print('Using ' + method + ' method for 2D to 3D')
    for key in blocks.keys():
        print('Classified {0} cells and {1} noncells for annocation block {2}.'.format(len(blocks[key]['pred_detect_' + method]), 
                                                                                       len(blocks[key]['pred_reject_' + method]), 
                                                                                       str(key)))

    print('Detection and Classification via ' + method + ' took {0} seconds.\n'.format(detect_times[method]))
# Out:
# Using flow method for 2D to 3D
# Classified 0 cells and 3 noncells for annocation block 4.
# Classified 0 cells and 1 noncells for annocation block 1.
# Classified 26 cells and 0 noncells for annocation block 3.
# Classified 0 cells and 0 noncells for annocation block 2.
# Detection and Classification via flow took 456.99028611183167 seconds.
#
# Using stitch method for 2D to 3D
# Classified 2 cells and 5 noncells for annocation block 4.
# Classified 1 cells and 0 noncells for annocation block 1.
# Classified 2 cells and 1 noncells for annocation block 3.
# Classified 1 cells and 1 noncells for annocation block 2.
# Detection and Classification via stitch took 226.4975070953369 seconds.

# %% [markdown]
# ### Plot Performance

# %%
# get metrics on model performance and plot results
import matplotlib.pyplot as plt
# %matplotlib inline

methods = ['flow', 'stitch']
max_dist = 10
trained = False

performance = evaluate.get_performance(blocks, methods, max_dist, trained)
evaluate.plot_performance(performance, methods)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13243/1321846715.py in <module>
#       7 trained = False
#       8
# ----> 9 performance = evaluate.get_performance(blocks, methods, max_dist, trained)
#      10 evaluate.plot_performance(performance, methods)
#
# ~/Documents/GitHub/LS_Segmentation_Evaluation/notebooks/utils/evaluate.py in get_performance(blocks, type_2D, max_dist, trained, get_keys)
#     179
#     180         else:
# --> 181             df_1 = annot_pred_overlap(blocks, dist, type_2D[0], trained, get_keys)
#     182             df_2 = annot_pred_overlap(blocks, dist, type_2D[1], trained, get_keys)
#     183             cm_1 = ConfusionMatrix(df_1['annotated'].values, df_1['predicted'].values, classes = [1.0, 2.0, 3.0])
#
# ~/Documents/GitHub/LS_Segmentation_Evaluation/notebooks/utils/evaluate.py in annot_pred_overlap(blocks, max_dist, type_2D, trained, get_keys)
#      75
#      76         if len(pred_reject) > 0:
# ---> 77             pred_points = np.concatenate((pred_detect, pred_reject), axis = 0)
#      78             pred_types = np.concatenate((np.ones((len(pred_detect), 1)),
#      79                                          np.ones((len(pred_reject), 1)) * 2), axis = 0)
#
# ~/miniconda3/envs/segment_compare/lib/python3.8/site-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
# Classification Matrix Plots
F1_scores = performance[2::3, :-1]
opt_vals = np.unravel_index(np.argmax(F1_scores, axis=None), F1_scores.shape)
metric_df = evaluate.annot_pred_overlap(blocks, opt_vals[0] + 1, methods[opt_vals[1]])

evaluate.plot_cm(metric_df)

# %% [markdown]
# ### Plot Example Images

# %%
# plot output from 3D flows => masks
from cellpose import plot, utils
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 600

seg_path = os.path.join(output_root, 'flow','block_4_signal_seg.npy') 
seg_data = np.load(seg_path, allow_pickle=True).item()

img = seg_data['img']
masks = seg_data['masks']
flows = seg_data['flows']

crop = [100, 150]

#plot cells with masks
for idx in range(60,91,10):
    maski = masks[idx, crop[0]:crop[1], crop[0]:crop[1]]
    flowi = flows[0][idx, crop[0]:crop[1], crop[0]:crop[1]]

    fig = plt.figure(figsize=(12,5))
    plot.show_segmentation(fig, img[idx, crop[0]:crop[1], crop[0]:crop[1]], maski, flowi)
    plt.tight_layout()
    plt.show()
